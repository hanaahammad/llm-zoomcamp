# %%
from openai import OpenAI

client = OpenAI(
    base_url='http://0.0.0.0:11435/v1/',
    api_key='ollama',
)

# %%
client.api_key
# Out:
# 'ollama'

# %%
mdls = client.models

# %%
type(mdls)
# Out:
# openai.resources.models.Models

# %%
#!pip install elasticsearch

# %%
from elasticsearch import Elasticsearch

# %%
es_client = Elasticsearch('http://localhost:9200')

# %%
es_client
# Out:
# <Elasticsearch(['http://localhost:9200'])>

# %%
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "text": {"type": "text"},
            "section": {"type": "text"},
            "question": {"type": "text"},
            "course": {"type": "keyword"} 
        }
    }
}

index_name = "course-questions"

es_client.indices.create(index=index_name, body=index_settings)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'course-questions'})

# %%
import requests 

docs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

# %%
from tqdm.auto import tqdm

# %%
for doc in tqdm(documents):
    es_client.index(index=index_name, document=doc)
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]

# %%
def elastic_search(query):
    search_query = {
        "size": 5,
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["question^3", "text", "section"],
                        "type": "best_fields"
                    }
                },
                "filter": {
                    "term": {
                        "course": "data-engineering-zoomcamp"
                    }
                }
            }
        }
    }

    response = es_client.search(index=index_name, body=search_query)
    
    result_docs = []
    
    for hit in response['hits']['hits']:
        result_docs.append(hit['_source'])
    
    return result_docs

# %%
def build_prompt(query, search_results):
    prompt_template = """
You're a course teaching assistant. Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}

CONTEXT: 
{context}
""".strip()

    context = ""
    
    for doc in search_results:
        context = context + f"section: {doc['section']}\nquestion: {doc['question']}\nanswer: {doc['text']}\n\n"
    
    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

def llm(prompt):
    response = client.chat.completions.create(
        model='gemma:b2',
        messages=[{"role": "user", "content": prompt}]
    )
    
    return response.choices[0].message.content

# %%
def rag(query):
    search_results = elastic_search(query)
    prompt = build_prompt(query, search_results)
    answer = llm(prompt)
    return answer

# %%
query = 'I just disovered the course. Can I still join it?'
rag(query)
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in write(self, buffer, timeout)
#      37                 self._sock.settimeout(timeout)
# ---> 38                 n = self._sock.send(buffer)
#      39                 buffer = buffer[n:]
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# WriteError                                Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      59     try:
# ---> 60         yield
#      61     except Exception as exc:  # noqa: PIE-786
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     217         with map_httpcore_exceptions():
# --> 218             resp = self._pool.handle_request(req)
#     219
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     252                 self.response_closed(status)
# --> 253                 raise exc
#     254             else:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     236             try:
# --> 237                 response = connection.handle_request(request)
#     238             except ConnectionNotAvailable:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      89
# ---> 90         return self._connection.handle_request(request)
#      91
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     111                 self._response_closed()
# --> 112             raise exc
#     113
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#      81             with Trace("http11.send_request_body", request, kwargs) as trace:
# ---> 82                 self._send_request_body(**kwargs)
#      83             with Trace(
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _send_request_body(self, request)
#     134             event = h11.Data(data=chunk)
# --> 135             self._send_event(event, timeout=timeout)
#     136
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _send_event(self, event, timeout)
#     143         if bytes_to_send is not None:
# --> 144             self._network_stream.write(bytes_to_send, timeout=timeout)
#     145
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in write(self, buffer, timeout)
#      34         exc_map: ExceptionMapping = {socket.timeout: WriteTimeout, OSError: WriteError}
# ---> 35         with map_exceptions(exc_map):
#      36             while buffer:
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc)
#      15         raise  # pragma: nocover
#
# WriteError: [Errno 32] Broken pipe
#
# The above exception was the direct cause of the following exception:
#
# WriteError                                Traceback (most recent call last)
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     876         try:
# --> 877             response = self._client.send(
#     878                 request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     907
# --> 908         response = self._send_handling_auth(
#     909             request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     935             while True:
# --> 936                 response = self._send_handling_redirects(
#     937                     request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     972
# --> 973             response = self._send_single_request(request)
#     974             try:
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1008         with request_context(request=request):
# -> 1009             response = transport.handle_request(request)
#    1010
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     216         )
# --> 217         with map_httpcore_exceptions():
#     218             resp = self._pool.handle_request(req)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      76         message = str(exc)
# ---> 77         raise mapped_exc(message) from exc
#      78
#
# WriteError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in read(self, max_bytes, timeout)
#      27             self._sock.settimeout(timeout)
# ---> 28             return self._sock.recv(max_bytes)
#      29
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ReadError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      59     try:
# ---> 60         yield
#      61     except Exception as exc:  # noqa: PIE-786
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     217         with map_httpcore_exceptions():
# --> 218             resp = self._pool.handle_request(req)
#     219
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     252                 self.response_closed(status)
# --> 253                 raise exc
#     254             else:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     236             try:
# --> 237                 response = connection.handle_request(request)
#     238             except ConnectionNotAvailable:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      89
# ---> 90         return self._connection.handle_request(request)
#      91
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     111                 self._response_closed()
# --> 112             raise exc
#     113
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#      90                     headers,
# ---> 91                 ) = self._receive_response_headers(**kwargs)
#      92                 trace.return_value = (
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     154         while True:
# --> 155             event = self._receive_event(timeout=timeout)
#     156             if isinstance(event, h11.Response):
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     190             if event is h11.NEED_DATA:
# --> 191                 data = self._network_stream.read(
#     192                     self.READ_NUM_BYTES, timeout=timeout
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in read(self, max_bytes, timeout)
#      25         exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# ---> 26         with map_exceptions(exc_map):
#      27             self._sock.settimeout(timeout)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc)
#      15         raise  # pragma: nocover
#
# ReadError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# ReadError                                 Traceback (most recent call last)
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     876         try:
# --> 877             response = self._client.send(
#     878                 request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     907
# --> 908         response = self._send_handling_auth(
#     909             request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     935             while True:
# --> 936                 response = self._send_handling_redirects(
#     937                     request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     972
# --> 973             response = self._send_single_request(request)
#     974             try:
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1008         with request_context(request=request):
# -> 1009             response = transport.handle_request(request)
#    1010
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     216         )
# --> 217         with map_httpcore_exceptions():
#     218             resp = self._pool.handle_request(req)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      76         message = str(exc)
# ---> 77         raise mapped_exc(message) from exc
#      78
#
# ReadError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in read(self, max_bytes, timeout)
#      27             self._sock.settimeout(timeout)
# ---> 28             return self._sock.recv(max_bytes)
#      29
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ReadError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      59     try:
# ---> 60         yield
#      61     except Exception as exc:  # noqa: PIE-786
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     217         with map_httpcore_exceptions():
# --> 218             resp = self._pool.handle_request(req)
#     219
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     252                 self.response_closed(status)
# --> 253                 raise exc
#     254             else:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     236             try:
# --> 237                 response = connection.handle_request(request)
#     238             except ConnectionNotAvailable:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      89
# ---> 90         return self._connection.handle_request(request)
#      91
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     111                 self._response_closed()
# --> 112             raise exc
#     113
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#      90                     headers,
# ---> 91                 ) = self._receive_response_headers(**kwargs)
#      92                 trace.return_value = (
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     154         while True:
# --> 155             event = self._receive_event(timeout=timeout)
#     156             if isinstance(event, h11.Response):
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     190             if event is h11.NEED_DATA:
# --> 191                 data = self._network_stream.read(
#     192                     self.READ_NUM_BYTES, timeout=timeout
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in read(self, max_bytes, timeout)
#      25         exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# ---> 26         with map_exceptions(exc_map):
#      27             self._sock.settimeout(timeout)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc)
#      15         raise  # pragma: nocover
#
# ReadError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# ReadError                                 Traceback (most recent call last)
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     876         try:
# --> 877             response = self._client.send(
#     878                 request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     907
# --> 908         response = self._send_handling_auth(
#     909             request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     935             while True:
# --> 936                 response = self._send_handling_redirects(
#     937                     request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     972
# --> 973             response = self._send_single_request(request)
#     974             try:
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1008         with request_context(request=request):
# -> 1009             response = transport.handle_request(request)
#    1010
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     216         )
# --> 217         with map_httpcore_exceptions():
#     218             resp = self._pool.handle_request(req)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      76         message = str(exc)
# ---> 77         raise mapped_exc(message) from exc
#      78
#
# ReadError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# /tmp/ipykernel_51853/1751360232.py in <cell line: 2>()
#       1 query = 'I just disovered the course. Can I still join it?'
# ----> 2 rag(query)
#
# /tmp/ipykernel_51853/3777559254.py in rag(query)
#       2     search_results = elastic_search(query)
#       3     prompt = build_prompt(query, search_results)
# ----> 4     answer = llm(prompt)
#       5     return answer
#
# /tmp/ipykernel_51853/1914496939.py in llm(prompt)
#      19
#      20 def llm(prompt):
# ---> 21     response = client.chat.completions.create(
#      22         model='gemma:b2',
#      23         messages=[{"role": "user", "content": prompt}]
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     301                         msg = f"Missing required argument: {quote(missing[0])}"
#     302                 raise TypeError(msg)
# --> 303             return func(*args, **kwargs)
#     304
#     305         return wrapper  # type: ignore
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/resources/chat/completions.py in create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     643         timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     644     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 645         return self._post(
#     646             "/chat/completions",
#     647             body=maybe_transform(
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1086             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1087         )
# -> 1088         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1089
#    1090     def patch(
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     851         stream_cls: type[_StreamT] | None = None,
#     852     ) -> ResponseT | _StreamT:
# --> 853         return self._request(
#     854             cast_to=cast_to,
#     855             options=options,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     894         except Exception as err:
#     895             if retries > 0:
# --> 896                 return self._retry_request(
#     897                     options,
#     898                     cast_to,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     956         time.sleep(timeout)
#     957
# --> 958         return self._request(
#     959             options=options,
#     960             cast_to=cast_to,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     894         except Exception as err:
#     895             if retries > 0:
# --> 896                 return self._retry_request(
#     897                     options,
#     898                     cast_to,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     956         time.sleep(timeout)
#     957
# --> 958         return self._request(
#     959             options=options,
#     960             cast_to=cast_to,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     903                 )
#     904
# --> 905             raise APIConnectionError(request=request) from err
#     906
#     907         log.debug(
#
# APIConnectionError: Connection error.

# %%
query = "What's the formula for energy?"
rag(query)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in read(self, max_bytes, timeout)
#      27             self._sock.settimeout(timeout)
# ---> 28             return self._sock.recv(max_bytes)
#      29
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ReadError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      59     try:
# ---> 60         yield
#      61     except Exception as exc:  # noqa: PIE-786
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     217         with map_httpcore_exceptions():
# --> 218             resp = self._pool.handle_request(req)
#     219
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     252                 self.response_closed(status)
# --> 253                 raise exc
#     254             else:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     236             try:
# --> 237                 response = connection.handle_request(request)
#     238             except ConnectionNotAvailable:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      89
# ---> 90         return self._connection.handle_request(request)
#      91
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     111                 self._response_closed()
# --> 112             raise exc
#     113
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#      90                     headers,
# ---> 91                 ) = self._receive_response_headers(**kwargs)
#      92                 trace.return_value = (
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     154         while True:
# --> 155             event = self._receive_event(timeout=timeout)
#     156             if isinstance(event, h11.Response):
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     190             if event is h11.NEED_DATA:
# --> 191                 data = self._network_stream.read(
#     192                     self.READ_NUM_BYTES, timeout=timeout
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in read(self, max_bytes, timeout)
#      25         exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# ---> 26         with map_exceptions(exc_map):
#      27             self._sock.settimeout(timeout)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc)
#      15         raise  # pragma: nocover
#
# ReadError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# ReadError                                 Traceback (most recent call last)
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     876         try:
# --> 877             response = self._client.send(
#     878                 request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     907
# --> 908         response = self._send_handling_auth(
#     909             request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     935             while True:
# --> 936                 response = self._send_handling_redirects(
#     937                     request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     972
# --> 973             response = self._send_single_request(request)
#     974             try:
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1008         with request_context(request=request):
# -> 1009             response = transport.handle_request(request)
#    1010
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     216         )
# --> 217         with map_httpcore_exceptions():
#     218             resp = self._pool.handle_request(req)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      76         message = str(exc)
# ---> 77         raise mapped_exc(message) from exc
#      78
#
# ReadError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# BrokenPipeError                           Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in write(self, buffer, timeout)
#      37                 self._sock.settimeout(timeout)
# ---> 38                 n = self._sock.send(buffer)
#      39                 buffer = buffer[n:]
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# WriteError                                Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      59     try:
# ---> 60         yield
#      61     except Exception as exc:  # noqa: PIE-786
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     217         with map_httpcore_exceptions():
# --> 218             resp = self._pool.handle_request(req)
#     219
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     252                 self.response_closed(status)
# --> 253                 raise exc
#     254             else:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     236             try:
# --> 237                 response = connection.handle_request(request)
#     238             except ConnectionNotAvailable:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      89
# ---> 90         return self._connection.handle_request(request)
#      91
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     111                 self._response_closed()
# --> 112             raise exc
#     113
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#      81             with Trace("http11.send_request_body", request, kwargs) as trace:
# ---> 82                 self._send_request_body(**kwargs)
#      83             with Trace(
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _send_request_body(self, request)
#     134             event = h11.Data(data=chunk)
# --> 135             self._send_event(event, timeout=timeout)
#     136
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _send_event(self, event, timeout)
#     143         if bytes_to_send is not None:
# --> 144             self._network_stream.write(bytes_to_send, timeout=timeout)
#     145
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in write(self, buffer, timeout)
#      34         exc_map: ExceptionMapping = {socket.timeout: WriteTimeout, OSError: WriteError}
# ---> 35         with map_exceptions(exc_map):
#      36             while buffer:
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc)
#      15         raise  # pragma: nocover
#
# WriteError: [Errno 32] Broken pipe
#
# The above exception was the direct cause of the following exception:
#
# WriteError                                Traceback (most recent call last)
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     876         try:
# --> 877             response = self._client.send(
#     878                 request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     907
# --> 908         response = self._send_handling_auth(
#     909             request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     935             while True:
# --> 936                 response = self._send_handling_redirects(
#     937                     request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     972
# --> 973             response = self._send_single_request(request)
#     974             try:
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1008         with request_context(request=request):
# -> 1009             response = transport.handle_request(request)
#    1010
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     216         )
# --> 217         with map_httpcore_exceptions():
#     218             resp = self._pool.handle_request(req)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      76         message = str(exc)
# ---> 77         raise mapped_exc(message) from exc
#      78
#
# WriteError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#       9     try:
# ---> 10         yield
#      11     except Exception as exc:  # noqa: PIE786
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in read(self, max_bytes, timeout)
#      27             self._sock.settimeout(timeout)
# ---> 28             return self._sock.recv(max_bytes)
#      29
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ReadError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      59     try:
# ---> 60         yield
#      61     except Exception as exc:  # noqa: PIE-786
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     217         with map_httpcore_exceptions():
# --> 218             resp = self._pool.handle_request(req)
#     219
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     252                 self.response_closed(status)
# --> 253                 raise exc
#     254             else:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     236             try:
# --> 237                 response = connection.handle_request(request)
#     238             except ConnectionNotAvailable:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      89
# ---> 90         return self._connection.handle_request(request)
#      91
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     111                 self._response_closed()
# --> 112             raise exc
#     113
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in handle_request(self, request)
#      90                     headers,
# ---> 91                 ) = self._receive_response_headers(**kwargs)
#      92                 trace.return_value = (
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     154         while True:
# --> 155             event = self._receive_event(timeout=timeout)
#     156             if isinstance(event, h11.Response):
#
# ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     190             if event is h11.NEED_DATA:
# --> 191                 data = self._network_stream.read(
#     192                     self.READ_NUM_BYTES, timeout=timeout
#
# ~/.local/lib/python3.10/site-packages/httpcore/backends/sync.py in read(self, max_bytes, timeout)
#      25         exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# ---> 26         with map_exceptions(exc_map):
#      27             self._sock.settimeout(timeout)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc)
#      15         raise  # pragma: nocover
#
# ReadError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# ReadError                                 Traceback (most recent call last)
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     876         try:
# --> 877             response = self._client.send(
#     878                 request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     907
# --> 908         response = self._send_handling_auth(
#     909             request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     935             while True:
# --> 936                 response = self._send_handling_redirects(
#     937                     request,
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     972
# --> 973             response = self._send_single_request(request)
#     974             try:
#
# ~/.local/lib/python3.10/site-packages/httpx/_client.py in _send_single_request(self, request)
#    1008         with request_context(request=request):
# -> 1009             response = transport.handle_request(request)
#    1010
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in handle_request(self, request)
#     216         )
# --> 217         with map_httpcore_exceptions():
#     218             resp = self._pool.handle_request(req)
#
# ~/miniconda3/envs/stenv/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      76         message = str(exc)
# ---> 77         raise mapped_exc(message) from exc
#      78
#
# ReadError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# /tmp/ipykernel_51853/3012747656.py in <cell line: 2>()
#       1 query = "What's the formula for energy?"
# ----> 2 rag(query)
#
# /tmp/ipykernel_51853/3777559254.py in rag(query)
#       2     search_results = elastic_search(query)
#       3     prompt = build_prompt(query, search_results)
# ----> 4     answer = llm(prompt)
#       5     return answer
#
# /tmp/ipykernel_51853/1914496939.py in llm(prompt)
#      19
#      20 def llm(prompt):
# ---> 21     response = client.chat.completions.create(
#      22         model='gemma:b2',
#      23         messages=[{"role": "user", "content": prompt}]
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     301                         msg = f"Missing required argument: {quote(missing[0])}"
#     302                 raise TypeError(msg)
# --> 303             return func(*args, **kwargs)
#     304
#     305         return wrapper  # type: ignore
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/resources/chat/completions.py in create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     643         timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     644     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 645         return self._post(
#     646             "/chat/completions",
#     647             body=maybe_transform(
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1086             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1087         )
# -> 1088         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1089
#    1090     def patch(
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     851         stream_cls: type[_StreamT] | None = None,
#     852     ) -> ResponseT | _StreamT:
# --> 853         return self._request(
#     854             cast_to=cast_to,
#     855             options=options,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     894         except Exception as err:
#     895             if retries > 0:
# --> 896                 return self._retry_request(
#     897                     options,
#     898                     cast_to,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     956         time.sleep(timeout)
#     957
# --> 958         return self._request(
#     959             options=options,
#     960             cast_to=cast_to,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     894         except Exception as err:
#     895             if retries > 0:
# --> 896                 return self._retry_request(
#     897                     options,
#     898                     cast_to,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     956         time.sleep(timeout)
#     957
# --> 958         return self._request(
#     959             options=options,
#     960             cast_to=cast_to,
#
# ~/miniconda3/envs/stenv/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     903                 )
#     904
# --> 905             raise APIConnectionError(request=request) from err
#     906
#     907         log.debug(
#
# APIConnectionError: Connection error.
